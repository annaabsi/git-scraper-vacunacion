# %%
import numpy as np
import pandas as pd
from zipfile import ZipFile
from urllib.request import urlopen
import io

# %%
req = Request('https://cloud.minsa.gob.pe/s/NctBnHXDnocgWAg/download')
req.add_header('User-Agent', 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:77.0) Gecko/20100101 Firefox/77.0')

# open and save the zip file onto computer
#url = urlopen(req)

file =zipfile.ZipFile((io.BytesIO(urlopen(req).read())))
file_name = file.namelist()[1]
#file_name
xls = pd.read_excel(file.open(file_name).read(), engine='openpyxl', index_col=0)  # <-- add .read()
xls
# Out:
#        TIPO SEGURO       SEXO EDAD TIEMPO EDAD ESTADO CIVIL  \
# Nº
# 1              SIS  MASCULINO    4        AÑOS      SOLTERO
# 2              SIS   FEMENINO   15     MINUTOS      SOLTERO
# 3         IGNORADO  MASCULINO   59        AÑOS      SOLTERO
# 4              SIS   FEMENINO   86        AÑOS      SOLTERO
# 5              SIS  MASCULINO   51        AÑOS      SOLTERO
# ...            ...        ...  ...         ...          ...
# 692543         SIS  MASCULINO   77        AÑOS       CASADO
# 692544         SIS   FEMENINO   86        AÑOS      SOLTERO
# 692545         SIS  MASCULINO   63        AÑOS      SOLTERO
# 692546         SIS   FEMENINO   78        AÑOS       CASADO
# 692547         SIS  MASCULINO    1        AÑOS      SOLTERO
#
#            NIVEL DE INSTRUCCIÓN COD# UBIGEO DOMICILIO PAIS DOMICILIO  \
# Nº
# 1                      IGNORADO    92-33-21-04-01-000           PERU
# 2       SUPERIOR NO UNIV. COMP.    92-33-12-08-06-000           PERU
# 3                      IGNORADO    92-33-24-01-01-000           PERU
# 4           PRIMARIA INCOMPLETA    92-33-21-03-13-000           PERU
# 5       SUPERIOR NO UNIV. COMP.    92-33-14-10-01-106           PERU
# ...                         ...                   ...            ...
# 692543  NINGUN NIVEL / ILETRADO    92-33-05-07-02-101           PERU
# 692544  NINGUN NIVEL / ILETRADO    92-33-05-04-03-101           PERU
# 692545  NINGUN NIVEL / ILETRADO    92-33-02-10-03-102           PERU
# 692546        PRIMARIA COMPLETA    92-33-02-10-10-000           PERU
# 692547  NINGUN NIVEL / ILETRADO    92-33-01-04-04-000           PERU
#
#        DEPARTAMENTO DOMICILIO PROVINCIA DOMICILIO  ...  \
# Nº                                                 ...
# 1                  SAN MARTIN    MARISCAL CACERES  ...
# 2                 LA LIBERTAD              ASCOPE  ...
# 3                      CALLAO              CALLAO  ...
# 4                  SAN MARTIN               LAMAS  ...
# 5                        LIMA                OYON  ...
# ...                       ...                 ...  ...
# 692543               AYACUCHO      VICTOR FAJARDO  ...
# 692544               AYACUCHO              LA MAR  ...
# 692545                 ANCASH            PALLASCA  ...
# 692546                 ANCASH            PALLASCA  ...
# 692547               AMAZONAS                LUYA  ...
#
#                                DEBIDO A (CAUSA B) CAUSA B (CIE-X)  \
# Nº
# 1                                 NEUMONIA SEVERA            J159
# 2       DIFICULTAD RESPIRATORIA DEL RECIEN NACIDO            P229
# 3                              SHOCK HIPOVOLEMICO    SIN REGISTRO
# 4                  HIPERLIPIDEMIA NO ESPECIFICADA            E785
# 5                                    SIN REGISTRO    SIN REGISTRO
# ...                                           ...             ...
# 692543                               SIN REGISTRO    SIN REGISTRO
# 692544       ESTADO ASMATICO.  ASMA AGUDA SEVERA.            J46X
# 692545          CAIDA POR DESLIZAMIENTO EN CALLES            W014
# 692546                               SIN REGISTRO    SIN REGISTRO
# 692547                     HIDROCEFALIA CONGENITA            P835
#
#                                        DEBIDO A (CAUSA C)  CAUSA C (CIE-X)  \
# Nº
# 1                                            SIN REGISTRO     SIN REGISTRO
# 2                                     INMATURIDAD EXTREMA             P072
# 3                                      SUCESO DE TRANSITO     SIN REGISTRO
# 4        ATEROSCLEROSIS GENERALIZADA Y LA NO ESPECIFICADA             I709
# 5                                            SIN REGISTRO     SIN REGISTRO
# ...                                                   ...              ...
# 692543                                       SIN REGISTRO     SIN REGISTRO
# 692544  ASMA NO ESPECIFICADO. ASMA DE APARICION TARDIA...             J459
# 692545                                       SIN REGISTRO     SIN REGISTRO
# 692546                                       SIN REGISTRO     SIN REGISTRO
# 692547                                       SIN REGISTRO     SIN REGISTRO
#
#            DEBIDO A (CAUSA D) CAUSA D (CIE-X)           DEBIDO A (CAUSA E)  \
# Nº
# 1                SIN REGISTRO    SIN REGISTRO  PARALISIS CEREBRAL INFANTIL
# 2                SIN REGISTRO    SIN REGISTRO                 SIN REGISTRO
# 3                SIN REGISTRO    SIN REGISTRO                 SIN REGISTRO
# 4       HIPERTENSION ESENCIAL            I10X                 SIN REGISTRO
# 5                SIN REGISTRO    SIN REGISTRO                 SIN REGISTRO
# ...                       ...             ...                          ...
# 692543           SIN REGISTRO    SIN REGISTRO                 SIN REGISTRO
# 692544           SIN REGISTRO    SIN REGISTRO                 SIN REGISTRO
# 692545           SIN REGISTRO    SIN REGISTRO                 SIN REGISTRO
# 692546           SIN REGISTRO    SIN REGISTRO                 SIN REGISTRO
# 692547           SIN REGISTRO    SIN REGISTRO                 SIN REGISTRO
#
#        CAUSA E (CIE-X) DEBIDO A (CAUSA F) CAUSA F (CIE-X)
# Nº
# 1                 G809       SIN REGISTRO    SIN REGISTRO
# 2         SIN REGISTRO       SIN REGISTRO    SIN REGISTRO
# 3         SIN REGISTRO       SIN REGISTRO    SIN REGISTRO
# 4         SIN REGISTRO       SIN REGISTRO    SIN REGISTRO
# 5         SIN REGISTRO       SIN REGISTRO    SIN REGISTRO
# ...                ...                ...             ...
# 692543    SIN REGISTRO       SIN REGISTRO    SIN REGISTRO
# 692544    SIN REGISTRO       SIN REGISTRO    SIN REGISTRO
# 692545    SIN REGISTRO       SIN REGISTRO    SIN REGISTRO
# 692546    SIN REGISTRO       SIN REGISTRO    SIN REGISTRO
# 692547    SIN REGISTRO       SIN REGISTRO    SIN REGISTRO
#
# [692547 rows x 30 columns]

# %%
for col in xls.columns: 
    print(col)
# Out:
# TIPO SEGURO
# SEXO
# EDAD
# TIEMPO EDAD
# ESTADO CIVIL
# NIVEL DE INSTRUCCIÓN
# COD# UBIGEO DOMICILIO
# PAIS DOMICILIO
# DEPARTAMENTO DOMICILIO
# PROVINCIA DOMICILIO
# DISTRITO DOMICILIO
# FECHA
# AÑO
# MES
# TIPO LUGAR
# INSTITUCION
# MUERTE VIOLENTA
# NECROPSIA
# DEBIDO A (CAUSA A)
# CAUSA A (CIE-X)
# DEBIDO A (CAUSA B)
# CAUSA B (CIE-X)
# DEBIDO A (CAUSA C)
# CAUSA C (CIE-X)
# DEBIDO A (CAUSA D)
# CAUSA D (CIE-X)
# DEBIDO A (CAUSA E)
# CAUSA E (CIE-X)
# DEBIDO A (CAUSA F)
# CAUSA F (CIE-X)

# %%
xls.isnull().sum()
# Out:
# TIPO SEGURO               0
# SEXO                      0
# EDAD                      0
# TIEMPO EDAD               0
# ESTADO CIVIL              0
# NIVEL DE INSTRUCCIÓN      0
# COD# UBIGEO DOMICILIO     0
# PAIS DOMICILIO            0
# DEPARTAMENTO DOMICILIO    0
# PROVINCIA DOMICILIO       0
# DISTRITO DOMICILIO        0
# FECHA                     0
# AÑO                       0
# MES                       0
# TIPO LUGAR                0
# INSTITUCION               0
# MUERTE VIOLENTA           0
# NECROPSIA                 0
# DEBIDO A (CAUSA A)        0
# CAUSA A (CIE-X)           0
# DEBIDO A (CAUSA B)        0
# CAUSA B (CIE-X)           0
# DEBIDO A (CAUSA C)        0
# CAUSA C (CIE-X)           0
# DEBIDO A (CAUSA D)        0
# CAUSA D (CIE-X)           0
# DEBIDO A (CAUSA E)        0
# CAUSA E (CIE-X)           0
# DEBIDO A (CAUSA F)        0
# CAUSA F (CIE-X)           0
# dtype: int64

# %%
xls.drop(['DEBIDO A (CAUSA A)','CAUSA A (CIE-X)', 'DEBIDO A (CAUSA B)', 'CAUSA B (CIE-X)', 'DEBIDO A (CAUSA C)', 'CAUSA C (CIE-X)', 'DEBIDO A (CAUSA D)', 'CAUSA D (CIE-X)', 'DEBIDO A (CAUSA E)', 'CAUSA E (CIE-X)', 'DEBIDO A (CAUSA F)','CAUSA F (CIE-X)'], axis=1, inplace=True)

# %%
xls
# Out:
#        TIPO SEGURO       SEXO EDAD TIEMPO EDAD ESTADO CIVIL  \
# Nº
# 1              SIS  MASCULINO    4        AÑOS      SOLTERO
# 2              SIS   FEMENINO   15     MINUTOS      SOLTERO
# 3         IGNORADO  MASCULINO   59        AÑOS      SOLTERO
# 4              SIS   FEMENINO   86        AÑOS      SOLTERO
# 5              SIS  MASCULINO   51        AÑOS      SOLTERO
# ...            ...        ...  ...         ...          ...
# 692543         SIS  MASCULINO   77        AÑOS       CASADO
# 692544         SIS   FEMENINO   86        AÑOS      SOLTERO
# 692545         SIS  MASCULINO   63        AÑOS      SOLTERO
# 692546         SIS   FEMENINO   78        AÑOS       CASADO
# 692547         SIS  MASCULINO    1        AÑOS      SOLTERO
#
#            NIVEL DE INSTRUCCIÓN COD# UBIGEO DOMICILIO PAIS DOMICILIO  \
# Nº
# 1                      IGNORADO    92-33-21-04-01-000           PERU
# 2       SUPERIOR NO UNIV. COMP.    92-33-12-08-06-000           PERU
# 3                      IGNORADO    92-33-24-01-01-000           PERU
# 4           PRIMARIA INCOMPLETA    92-33-21-03-13-000           PERU
# 5       SUPERIOR NO UNIV. COMP.    92-33-14-10-01-106           PERU
# ...                         ...                   ...            ...
# 692543  NINGUN NIVEL / ILETRADO    92-33-05-07-02-101           PERU
# 692544  NINGUN NIVEL / ILETRADO    92-33-05-04-03-101           PERU
# 692545  NINGUN NIVEL / ILETRADO    92-33-02-10-03-102           PERU
# 692546        PRIMARIA COMPLETA    92-33-02-10-10-000           PERU
# 692547  NINGUN NIVEL / ILETRADO    92-33-01-04-04-000           PERU
#
#        DEPARTAMENTO DOMICILIO PROVINCIA DOMICILIO DISTRITO DOMICILIO  \
# Nº
# 1                  SAN MARTIN    MARISCAL CACERES            JUANJUI
# 2                 LA LIBERTAD              ASCOPE             PAIJAN
# 3                      CALLAO              CALLAO             CALLAO
# 4                  SAN MARTIN               LAMAS          TABALOSOS
# 5                        LIMA                OYON               OYON
# ...                       ...                 ...                ...
# 692543               AYACUCHO      VICTOR FAJARDO          ALCAMENCA
# 692544               AYACUCHO              LA MAR               AYNA
# 692545                 ANCASH            PALLASCA          CONCHUCOS
# 692546                 ANCASH            PALLASCA         SANTA ROSA
# 692547               AMAZONAS                LUYA           COLCAMAR
#
#             FECHA   AÑO  MES   TIPO LUGAR        INSTITUCION MUERTE VIOLENTA  \
# Nº
# 1      2020-01-17  2020    1         EESS  GOBIERNO REGIONAL    SIN REGISTRO
# 2      2021-01-19  2021    1         EESS            ESSALUD    SIN REGISTRO
# 3      2021-01-30  2021    1  VIA PUBLICA       SIN REGISTRO    NO SE CONOCE
# 4      2020-01-03  2020    1    DOMICILIO       SIN REGISTRO    SIN REGISTRO
# 5      2021-01-10  2021    1  VIA PUBLICA       SIN REGISTRO    SIN REGISTRO
# ...           ...   ...  ...          ...                ...             ...
# 692543 2020-12-07  2020   12    DOMICILIO       SIN REGISTRO    SIN REGISTRO
# 692544 2020-12-17  2020   12    DOMICILIO       SIN REGISTRO    SIN REGISTRO
# 692545 2020-12-22  2020   12    DOMICILIO       SIN REGISTRO    SIN REGISTRO
# 692546 2020-12-11  2020   12    DOMICILIO       SIN REGISTRO    SIN REGISTRO
# 692547 2020-12-23  2020   12    DOMICILIO       SIN REGISTRO    SIN REGISTRO
#
#                       NECROPSIA
# Nº
# 1       NO SE REALIZÓ NECROPSIA
# 2       NO SE REALIZÓ NECROPSIA
# 3       SI SE REALIZÓ NECROPSIA
# 4       NO SE REALIZÓ NECROPSIA
# 5       NO SE REALIZÓ NECROPSIA
# ...                         ...
# 692543  NO SE REALIZÓ NECROPSIA
# 692544  NO SE REALIZÓ NECROPSIA
# 692545  NO SE REALIZÓ NECROPSIA
# 692546  NO SE REALIZÓ NECROPSIA
# 692547  NO SE REALIZÓ NECROPSIA
#
# [692547 rows x 18 columns]

# %%
xls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 692547 entries, 1 to 692547
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   TIPO SEGURO             692547 non-null  object
#  1   SEXO                    692547 non-null  object
#  2   EDAD                    692547 non-null  object
#  3   TIEMPO EDAD             692547 non-null  object
#  4   ESTADO CIVIL            692547 non-null  object
#  5   NIVEL DE INSTRUCCIÓN    692547 non-null  object
#  6   COD# UBIGEO DOMICILIO   692547 non-null  object
#  7   PAIS DOMICILIO          692547 non-null  object
#  8   DEPARTAMENTO DOMICILIO  692547 non-null  object
#  9   PROVINCIA DOMICILIO     692547 non-null  object
#  10  DISTRITO DOMICILIO      692547 non-null  object
#  11  FECHA                   692547 non-null  datetime64[ns]
#  12  AÑO                     692547 non-null  int64
#  13  MES                     692547 non-null  int64
#  14  TIPO LUGAR              692547 non-null  object
#  15  INSTITUCION             692547 non-null  object
#  16  MUERTE VIOLENTA         692547 non-null  object
#  17  NECROPSIA               692547 non-null  object
# dtypes: datetime64[ns](1), int64(2), object(15)
# memory usage: 100.4+ MB

# %%
xls.describe()
# Out:
#                  AÑO            MES
# count  692547.000000  692547.000000
# mean     2019.301236       5.907024
# std         1.355441       3.257479
# min      2017.000000       1.000000
# 25%      2018.000000       3.000000
# 50%      2020.000000       5.000000
# 75%      2020.000000       8.000000
# max      2021.000000      12.000000

# %%
#pd.xls.replace('SIN REGISTRO', np.nan)
xls = xls.rename(columns={"COD# UBIGEO DOMICILIO": "UBIGEO","PAIS DOMICILIO": "PAIS","DEPARTAMENTO DOMICILIO": "DEPARTAMENTO", "PROVINCIA DOMICILIO": "PROVINCIA", "DISTRITO DOMICILIO": "DISTRITO"})

# %%
xls
# Out:
#        TIPO SEGURO       SEXO EDAD TIEMPO EDAD ESTADO CIVIL  \
# Nº
# 1              SIS  MASCULINO    4        AÑOS      SOLTERO
# 2              SIS   FEMENINO   15     MINUTOS      SOLTERO
# 3         IGNORADO  MASCULINO   59        AÑOS      SOLTERO
# 4              SIS   FEMENINO   86        AÑOS      SOLTERO
# 5              SIS  MASCULINO   51        AÑOS      SOLTERO
# ...            ...        ...  ...         ...          ...
# 692543         SIS  MASCULINO   77        AÑOS       CASADO
# 692544         SIS   FEMENINO   86        AÑOS      SOLTERO
# 692545         SIS  MASCULINO   63        AÑOS      SOLTERO
# 692546         SIS   FEMENINO   78        AÑOS       CASADO
# 692547         SIS  MASCULINO    1        AÑOS      SOLTERO
#
#            NIVEL DE INSTRUCCIÓN              UBIGEO  PAIS DEPARTAMENTO  \
# Nº
# 1                      IGNORADO  92-33-21-04-01-000  PERU   SAN MARTIN
# 2       SUPERIOR NO UNIV. COMP.  92-33-12-08-06-000  PERU  LA LIBERTAD
# 3                      IGNORADO  92-33-24-01-01-000  PERU       CALLAO
# 4           PRIMARIA INCOMPLETA  92-33-21-03-13-000  PERU   SAN MARTIN
# 5       SUPERIOR NO UNIV. COMP.  92-33-14-10-01-106  PERU         LIMA
# ...                         ...                 ...   ...          ...
# 692543  NINGUN NIVEL / ILETRADO  92-33-05-07-02-101  PERU     AYACUCHO
# 692544  NINGUN NIVEL / ILETRADO  92-33-05-04-03-101  PERU     AYACUCHO
# 692545  NINGUN NIVEL / ILETRADO  92-33-02-10-03-102  PERU       ANCASH
# 692546        PRIMARIA COMPLETA  92-33-02-10-10-000  PERU       ANCASH
# 692547  NINGUN NIVEL / ILETRADO  92-33-01-04-04-000  PERU     AMAZONAS
#
#                PROVINCIA    DISTRITO      FECHA   AÑO  MES   TIPO LUGAR  \
# Nº
# 1       MARISCAL CACERES     JUANJUI 2020-01-17  2020    1         EESS
# 2                 ASCOPE      PAIJAN 2021-01-19  2021    1         EESS
# 3                 CALLAO      CALLAO 2021-01-30  2021    1  VIA PUBLICA
# 4                  LAMAS   TABALOSOS 2020-01-03  2020    1    DOMICILIO
# 5                   OYON        OYON 2021-01-10  2021    1  VIA PUBLICA
# ...                  ...         ...        ...   ...  ...          ...
# 692543    VICTOR FAJARDO   ALCAMENCA 2020-12-07  2020   12    DOMICILIO
# 692544            LA MAR        AYNA 2020-12-17  2020   12    DOMICILIO
# 692545          PALLASCA   CONCHUCOS 2020-12-22  2020   12    DOMICILIO
# 692546          PALLASCA  SANTA ROSA 2020-12-11  2020   12    DOMICILIO
# 692547              LUYA    COLCAMAR 2020-12-23  2020   12    DOMICILIO
#
#               INSTITUCION MUERTE VIOLENTA                NECROPSIA
# Nº
# 1       GOBIERNO REGIONAL    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
# 2                 ESSALUD    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
# 3            SIN REGISTRO    NO SE CONOCE  SI SE REALIZÓ NECROPSIA
# 4            SIN REGISTRO    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
# 5            SIN REGISTRO    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
# ...                   ...             ...                      ...
# 692543       SIN REGISTRO    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
# 692544       SIN REGISTRO    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
# 692545       SIN REGISTRO    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
# 692546       SIN REGISTRO    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
# 692547       SIN REGISTRO    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
#
# [692547 rows x 18 columns]

# %%
xls = xls.sort_values(by = 'FECHA')
xls['FECHA'] = pd.to_datetime(xls['FECHA'], errors='coerce', dayfirst=True)
xls['FECHA'] = pd.to_datetime(xls['FECHA'], format='%y-%m-%d', errors='ignore')
xls
# Out:
#        TIPO SEGURO           SEXO EDAD TIEMPO EDAD          ESTADO CIVIL  \
# Nº
# 523367    PRIVADOS       FEMENINO   66        AÑOS                CASADO
# 462278    IGNORADO  INDETERMINADO   90        AÑOS               SOLTERO
# 464610         SIS       FEMENINO   83        AÑOS  CONVIVIENT/CONCUBINA
# 462284    IGNORADO      MASCULINO   75        AÑOS                CASADO
# 458880    IGNORADO       FEMENINO   55        AÑOS               SOLTERO
# ...            ...            ...  ...         ...                   ...
# 297644         SIS       FEMENINO   66        AÑOS                CASADO
# 297643     ESSALUD       FEMENINO   39        AÑOS               SOLTERO
# 297641    IGNORADO      MASCULINO   78        AÑOS               SOLTERO
# 297636         SIS      MASCULINO   35        AÑOS               SOLTERO
# 297790     ESSALUD       FEMENINO   94        AÑOS                 VIUDO
#
#            NIVEL DE INSTRUCCIÓN              UBIGEO  PAIS DEPARTAMENTO  \
# Nº
# 523367        PRIMARIA COMPLETA  92-33-15-01-13-000  PERU       LORETO
# 462278      PRIMARIA INCOMPLETA  92-33-14-01-06-000  PERU         LIMA
# 464610  NINGUN NIVEL / ILETRADO  92-33-06-06-15-000  PERU    CAJAMARCA
# 462284      SECUNDARIA COMPLETA  92-33-14-01-06-000  PERU         LIMA
# 458880  SUPERIOR NO UNIV. COMP.  92-33-13-01-12-000  PERU   LAMBAYEQUE
# ...                         ...                 ...   ...          ...
# 297644      SECUNDARIA COMPLETA  92-33-11-09-01-000  PERU        JUNIN
# 297643                 IGNORADO  92-33-14-01-26-000  PERU         LIMA
# 297641      SECUNDARIA COMPLETA  92-33-11-01-01-000  PERU        JUNIN
# 297636  SUPERIOR NO UNIV. COMP.  92-33-20-01-01-000  PERU         PUNO
# 297790      PRIMARIA INCOMPLETA  92-33-14-01-42-000  PERU         LIMA
#
#        PROVINCIA              DISTRITO      FECHA   AÑO  MES   TIPO LUGAR  \
# Nº
# 523367    MAYNAS     SAN JUAN BAUTISTA 2017-01-01  2017    1         EESS
# 462278      LIMA                 COMAS 2017-01-01  2017    1  EN TRANSITO
# 464610     CHOTA             TACABAMBA 2017-01-01  2017    1         EESS
# 462284      LIMA                 COMAS 2017-01-01  2017    1    DOMICILIO
# 458880  CHICLAYO   JOSE LEONARDO ORTIZ 2017-01-01  2017    1         EESS
# ...          ...                   ...        ...   ...  ...          ...
# 297644   CHUPACA               CHUPACA 2021-06-08  2021    6         EESS
# 297643      LIMA  SAN MARTIN DE PORRES 2021-06-08  2021    6         EESS
# 297641  HUANCAYO              HUANCAYO 2021-06-08  2021    6    DOMICILIO
# 297636      PUNO                  PUNO 2021-06-08  2021    6         EESS
# 297790      LIMA            LOS OLIVOS 2021-06-08  2021    6         EESS
#
#               INSTITUCION MUERTE VIOLENTA                NECROPSIA
# Nº
# 523367            PRIVADO    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
# 462278       SIN REGISTRO    SIN REGISTRO             SIN REGISTRO
# 464610  GOBIERNO REGIONAL    SIN REGISTRO             SIN REGISTRO
# 462284       SIN REGISTRO    SIN REGISTRO             SIN REGISTRO
# 458880            ESSALUD    SIN REGISTRO             SIN REGISTRO
# ...                   ...             ...                      ...
# 297644  GOBIERNO REGIONAL    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
# 297643            ESSALUD    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
# 297641       SIN REGISTRO    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
# 297636  GOBIERNO REGIONAL    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
# 297790            ESSALUD    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
#
# [692547 rows x 18 columns]

# %%
xls['FECHA'].replace('SIN REGISTRO', np.nan)
xls['EDAD'].replace('SIN REGISTRO', np.nan)
xls['FECHA'].dropna()
xls['EDAD'].dropna()
# Out:
# Nº
# 523367    66
# 462278    90
# 464610    83
# 462284    75
# 458880    55
#           ..
# 297644    66
# 297643    39
# 297641    78
# 297636    35
# 297790    94
# Name: EDAD, Length: 692547, dtype: object

# %%
xls
# Out:
#        TIPO SEGURO           SEXO EDAD TIEMPO EDAD          ESTADO CIVIL  \
# Nº
# 523367    PRIVADOS       FEMENINO   66        AÑOS                CASADO
# 462278    IGNORADO  INDETERMINADO   90        AÑOS               SOLTERO
# 464610         SIS       FEMENINO   83        AÑOS  CONVIVIENT/CONCUBINA
# 462284    IGNORADO      MASCULINO   75        AÑOS                CASADO
# 458880    IGNORADO       FEMENINO   55        AÑOS               SOLTERO
# ...            ...            ...  ...         ...                   ...
# 297644         SIS       FEMENINO   66        AÑOS                CASADO
# 297643     ESSALUD       FEMENINO   39        AÑOS               SOLTERO
# 297641    IGNORADO      MASCULINO   78        AÑOS               SOLTERO
# 297636         SIS      MASCULINO   35        AÑOS               SOLTERO
# 297790     ESSALUD       FEMENINO   94        AÑOS                 VIUDO
#
#            NIVEL DE INSTRUCCIÓN              UBIGEO  PAIS DEPARTAMENTO  \
# Nº
# 523367        PRIMARIA COMPLETA  92-33-15-01-13-000  PERU       LORETO
# 462278      PRIMARIA INCOMPLETA  92-33-14-01-06-000  PERU         LIMA
# 464610  NINGUN NIVEL / ILETRADO  92-33-06-06-15-000  PERU    CAJAMARCA
# 462284      SECUNDARIA COMPLETA  92-33-14-01-06-000  PERU         LIMA
# 458880  SUPERIOR NO UNIV. COMP.  92-33-13-01-12-000  PERU   LAMBAYEQUE
# ...                         ...                 ...   ...          ...
# 297644      SECUNDARIA COMPLETA  92-33-11-09-01-000  PERU        JUNIN
# 297643                 IGNORADO  92-33-14-01-26-000  PERU         LIMA
# 297641      SECUNDARIA COMPLETA  92-33-11-01-01-000  PERU        JUNIN
# 297636  SUPERIOR NO UNIV. COMP.  92-33-20-01-01-000  PERU         PUNO
# 297790      PRIMARIA INCOMPLETA  92-33-14-01-42-000  PERU         LIMA
#
#        PROVINCIA              DISTRITO      FECHA   AÑO  MES   TIPO LUGAR  \
# Nº
# 523367    MAYNAS     SAN JUAN BAUTISTA 2017-01-01  2017    1         EESS
# 462278      LIMA                 COMAS 2017-01-01  2017    1  EN TRANSITO
# 464610     CHOTA             TACABAMBA 2017-01-01  2017    1         EESS
# 462284      LIMA                 COMAS 2017-01-01  2017    1    DOMICILIO
# 458880  CHICLAYO   JOSE LEONARDO ORTIZ 2017-01-01  2017    1         EESS
# ...          ...                   ...        ...   ...  ...          ...
# 297644   CHUPACA               CHUPACA 2021-06-08  2021    6         EESS
# 297643      LIMA  SAN MARTIN DE PORRES 2021-06-08  2021    6         EESS
# 297641  HUANCAYO              HUANCAYO 2021-06-08  2021    6    DOMICILIO
# 297636      PUNO                  PUNO 2021-06-08  2021    6         EESS
# 297790      LIMA            LOS OLIVOS 2021-06-08  2021    6         EESS
#
#               INSTITUCION MUERTE VIOLENTA                NECROPSIA
# Nº
# 523367            PRIVADO    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
# 462278       SIN REGISTRO    SIN REGISTRO             SIN REGISTRO
# 464610  GOBIERNO REGIONAL    SIN REGISTRO             SIN REGISTRO
# 462284       SIN REGISTRO    SIN REGISTRO             SIN REGISTRO
# 458880            ESSALUD    SIN REGISTRO             SIN REGISTRO
# ...                   ...             ...                      ...
# 297644  GOBIERNO REGIONAL    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
# 297643            ESSALUD    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
# 297641       SIN REGISTRO    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
# 297636  GOBIERNO REGIONAL    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
# 297790            ESSALUD    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
#
# [692547 rows x 18 columns]

# %%
start_date = "2019-01-01"

after_start_date = xls["FECHA"] >= start_date
filtered_dates = xls.loc[after_start_date]

xls_edad_anos = filtered_dates[filtered_dates['TIEMPO EDAD']=='AÑOS']
xls_edad_anos
# Out:
#         TIPO SEGURO       SEXO EDAD TIEMPO EDAD ESTADO CIVIL  \
# Nº
# 652896     IGNORADO  MASCULINO   76        AÑOS      SOLTERO
# 563009     IGNORADO   FEMENINO   65        AÑOS       CASADO
# 562869          SIS   FEMENINO   48        AÑOS      SOLTERO
# 564881      ESSALUD  MASCULINO   54        AÑOS   DIVORCIADO
# 564877  SANIDAD FAP  MASCULINO   89        AÑOS       CASADO
# ...             ...        ...  ...         ...          ...
# 297644          SIS   FEMENINO   66        AÑOS       CASADO
# 297643      ESSALUD   FEMENINO   39        AÑOS      SOLTERO
# 297641     IGNORADO  MASCULINO   78        AÑOS      SOLTERO
# 297636          SIS  MASCULINO   35        AÑOS      SOLTERO
# 297790      ESSALUD   FEMENINO   94        AÑOS        VIUDO
#
#            NIVEL DE INSTRUCCIÓN              UBIGEO  PAIS DEPARTAMENTO  \
# Nº
# 652896      SECUNDARIA COMPLETA  92-33-24-01-06-000  PERU       CALLAO
# 563009    SECUNDARIA INCOMPLETA  92-33-14-01-35-000  PERU         LIMA
# 562869      PRIMARIA INCOMPLETA  92-33-06-05-02-000  PERU    CAJAMARCA
# 564881      SECUNDARIA COMPLETA  92-33-14-01-36-000  PERU         LIMA
# 564877  SUPERIOR NO UNIV. COMP.  92-33-04-01-07-000  PERU     AREQUIPA
# ...                         ...                 ...   ...          ...
# 297644      SECUNDARIA COMPLETA  92-33-11-09-01-000  PERU        JUNIN
# 297643                 IGNORADO  92-33-14-01-26-000  PERU         LIMA
# 297641      SECUNDARIA COMPLETA  92-33-11-01-01-000  PERU        JUNIN
# 297636  SUPERIOR NO UNIV. COMP.  92-33-20-01-01-000  PERU         PUNO
# 297790      PRIMARIA INCOMPLETA  92-33-14-01-42-000  PERU         LIMA
#
#        PROVINCIA                DISTRITO      FECHA   AÑO  MES TIPO LUGAR  \
# Nº
# 652896    CALLAO              VENTANILLA 2019-01-01  2019    1  DOMICILIO
# 563009      LIMA             EL AGUSTINO 2019-01-01  2019    1  DOMICILIO
# 562869   CUTERVO                CALLAYUC 2019-01-01  2019    1       EESS
# 564881      LIMA  SAN JUAN DE MIRAFLORES 2019-01-01  2019    1       EESS
# 564877  AREQUIPA              MIRAFLORES 2019-01-01  2019    1       EESS
# ...          ...                     ...        ...   ...  ...        ...
# 297644   CHUPACA                 CHUPACA 2021-06-08  2021    6       EESS
# 297643      LIMA    SAN MARTIN DE PORRES 2021-06-08  2021    6       EESS
# 297641  HUANCAYO                HUANCAYO 2021-06-08  2021    6  DOMICILIO
# 297636      PUNO                    PUNO 2021-06-08  2021    6       EESS
# 297790      LIMA              LOS OLIVOS 2021-06-08  2021    6       EESS
#
#               INSTITUCION MUERTE VIOLENTA                NECROPSIA
# Nº
# 652896       SIN REGISTRO    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
# 563009       SIN REGISTRO    SIN REGISTRO  SI SE REALIZÓ NECROPSIA
# 562869  GOBIERNO REGIONAL    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
# 564881            ESSALUD    SIN REGISTRO  SI SE REALIZÓ NECROPSIA
# 564877  GOBIERNO REGIONAL    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
# ...                   ...             ...                      ...
# 297644  GOBIERNO REGIONAL    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
# 297643            ESSALUD    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
# 297641       SIN REGISTRO    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
# 297636  GOBIERNO REGIONAL    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
# 297790            ESSALUD    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
#
# [469999 rows x 18 columns]

# %%
xls_edad_anos.EDAD = pd.to_numeric(xls_edad_anos.EDAD, errors='coerce')
xls_edad_anos
#xls_edad_anos['EDAD'].astype(str).astype(int)
#xls_edad_anos['EDAD']
# Out:
# /home/geny/.local/lib/python3.7/site-packages/pandas/core/generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#         TIPO SEGURO       SEXO  EDAD TIEMPO EDAD ESTADO CIVIL  \
# Nº
# 652896     IGNORADO  MASCULINO    76        AÑOS      SOLTERO
# 563009     IGNORADO   FEMENINO    65        AÑOS       CASADO
# 562869          SIS   FEMENINO    48        AÑOS      SOLTERO
# 564881      ESSALUD  MASCULINO    54        AÑOS   DIVORCIADO
# 564877  SANIDAD FAP  MASCULINO    89        AÑOS       CASADO
# ...             ...        ...   ...         ...          ...
# 297644          SIS   FEMENINO    66        AÑOS       CASADO
# 297643      ESSALUD   FEMENINO    39        AÑOS      SOLTERO
# 297641     IGNORADO  MASCULINO    78        AÑOS      SOLTERO
# 297636          SIS  MASCULINO    35        AÑOS      SOLTERO
# 297790      ESSALUD   FEMENINO    94        AÑOS        VIUDO
#
#            NIVEL DE INSTRUCCIÓN              UBIGEO  PAIS DEPARTAMENTO  \
# Nº
# 652896      SECUNDARIA COMPLETA  92-33-24-01-06-000  PERU       CALLAO
# 563009    SECUNDARIA INCOMPLETA  92-33-14-01-35-000  PERU         LIMA
# 562869      PRIMARIA INCOMPLETA  92-33-06-05-02-000  PERU    CAJAMARCA
# 564881      SECUNDARIA COMPLETA  92-33-14-01-36-000  PERU         LIMA
# 564877  SUPERIOR NO UNIV. COMP.  92-33-04-01-07-000  PERU     AREQUIPA
# ...                         ...                 ...   ...          ...
# 297644      SECUNDARIA COMPLETA  92-33-11-09-01-000  PERU        JUNIN
# 297643                 IGNORADO  92-33-14-01-26-000  PERU         LIMA
# 297641      SECUNDARIA COMPLETA  92-33-11-01-01-000  PERU        JUNIN
# 297636  SUPERIOR NO UNIV. COMP.  92-33-20-01-01-000  PERU         PUNO
# 297790      PRIMARIA INCOMPLETA  92-33-14-01-42-000  PERU         LIMA
#
#        PROVINCIA                DISTRITO      FECHA   AÑO  MES TIPO LUGAR  \
# Nº
# 652896    CALLAO              VENTANILLA 2019-01-01  2019    1  DOMICILIO
# 563009      LIMA             EL AGUSTINO 2019-01-01  2019    1  DOMICILIO
# 562869   CUTERVO                CALLAYUC 2019-01-01  2019    1       EESS
# 564881      LIMA  SAN JUAN DE MIRAFLORES 2019-01-01  2019    1       EESS
# 564877  AREQUIPA              MIRAFLORES 2019-01-01  2019    1       EESS
# ...          ...                     ...        ...   ...  ...        ...
# 297644   CHUPACA                 CHUPACA 2021-06-08  2021    6       EESS
# 297643      LIMA    SAN MARTIN DE PORRES 2021-06-08  2021    6       EESS
# 297641  HUANCAYO                HUANCAYO 2021-06-08  2021    6  DOMICILIO
# 297636      PUNO                    PUNO 2021-06-08  2021    6       EESS
# 297790      LIMA              LOS OLIVOS 2021-06-08  2021    6       EESS
#
#               INSTITUCION MUERTE VIOLENTA                NECROPSIA
# Nº
# 652896       SIN REGISTRO    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
# 563009       SIN REGISTRO    SIN REGISTRO  SI SE REALIZÓ NECROPSIA
# 562869  GOBIERNO REGIONAL    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
# 564881            ESSALUD    SIN REGISTRO  SI SE REALIZÓ NECROPSIA
# 564877  GOBIERNO REGIONAL    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
# ...                   ...             ...                      ...
# 297644  GOBIERNO REGIONAL    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
# 297643            ESSALUD    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
# 297641       SIN REGISTRO    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
# 297636  GOBIERNO REGIONAL    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
# 297790            ESSALUD    SIN REGISTRO  NO SE REALIZÓ NECROPSIA
#
# [469999 rows x 18 columns]

# %%
#bins = [17, 59, 69, 79, 130]

#rs = pd.cut(xls_edad_anos['EDAD'], bins)
#rs

df_total = xls_edad_anos.groupby(['FECHA', 'AÑO']).size().unstack()
df_total = df_total.rename(columns=str).reset_index()
# df.drop(columns=df.columns[0], 
#         axis=1, 
#         inplace=True)
df_total
# Out:
# AÑO      FECHA   2019  2020   2021
# 0   2019-01-01  329.0   NaN    NaN
# 1   2019-01-02  306.0   NaN    NaN
# 2   2019-01-03  314.0   NaN    NaN
# 3   2019-01-04  290.0   NaN    NaN
# 4   2019-01-05  303.0   NaN    NaN
# ..         ...    ...   ...    ...
# 885 2021-06-04    NaN   NaN  657.0
# 886 2021-06-05    NaN   NaN  682.0
# 887 2021-06-06    NaN   NaN  638.0
# 888 2021-06-07    NaN   NaN  627.0
# 889 2021-06-08    NaN   NaN  316.0
#
# [890 rows x 4 columns]

# %%
df_total.to_csv('fallecidos_total.csv' , index=False)

# %%
bins = [17, 59, 69, 79, 130]

rs = pd.cut(xls_edad_anos['EDAD'], bins)
#rs

df = xls_edad_anos.groupby(['FECHA', rs]).size().unstack()
df = df.rename(columns=str).reset_index()
# df.drop(columns=df.columns[0], 
#         axis=1, 
#         inplace=True)
df = df.rename(columns={'(17, 59]': '18-59', '(59, 69]': '60-69', '(69, 79]': '70-79', '(79, 130]' : '80+'})
df
# Out:
# EDAD      FECHA  18-59  60-69  70-79  80+
# 0    2019-01-01     96     42     62  117
# 1    2019-01-02     85     44     64  103
# 2    2019-01-03     83     35     62  123
# 3    2019-01-04     69     36     66  110
# 4    2019-01-05     77     46     58  118
# ..          ...    ...    ...    ...  ...
# 885  2021-06-04    182    157    128  185
# 886  2021-06-05    189    142    153  187
# 887  2021-06-06    174    138    141  180
# 888  2021-06-07    183    145    126  164
# 889  2021-06-08     76     85     75   79
#
# [890 rows x 5 columns]

# %%
df.to_csv('fallecidos_edad.csv' , index=False)

# %%
bins = [0, 18, 59, 69, 80, 130]

rs = pd.cut(xls_edad_anos['EDAD'], bins)
#rs

df_anos = xls_edad_anos.groupby(['FECHA',rs]).size().unstack()
df_anos = df_anos.rename(columns=str).reset_index()
df_anos
# Out:
# EDAD      FECHA  (0, 17]  (17, 30]  (30, 40]  (40, 60]  (60, 80]  (80, 100]  \
# 0    2017-01-01        9        24        15        48        88         72
# 1    2017-01-02        8         8        14        44        74         84
# 2    2017-01-03        6         4        13        28        77         79
# 3    2017-01-04        7         9        13        37        65         88
# 4    2017-01-05        6         6         4        47        73         62
# ...         ...      ...       ...       ...       ...       ...        ...
# 1596 2021-05-16        6        20        35       208       409        225
# 1597 2021-05-17       12        15        37       209       378        222
# 1598 2021-05-18        8        17        39       197       369        202
# 1599 2021-05-19       12        20        35       207       392        179
# 1600 2021-05-20        2        12        14       132       233        124
#
# EDAD  (100, 130]
# 0              2
# 1              0
# 2              0
# 3              1
# 4              0
# ...          ...
# 1596           1
# 1597           1
# 1598           1
# 1599           3
# 1600           0
#
# [1601 rows x 8 columns]
